# %% [markdown]
# ## Import Dependancies

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Mounted at /content/drive

# %%
# Import our dependencies
from sklearn.model_selection import train_test_split
from sklearn.preprocessing import StandardScaler
import pandas as pd
import tensorflow as tf
from sklearn import linear_model
import matplotlib.pyplot as plt
import numpy as np
df_c = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/p4/FINAL_data.csv")
df_c
# Out:
#      Unnamed: 0                   Country  ...  government_corruption Generosity
# 0             0               Switzerland  ...               0.419780   0.296780
# 1             1                   Iceland  ...               0.141450   0.436300
# 2             2                   Denmark  ...               0.483570   0.341390
# 3             3                    Norway  ...               0.365030   0.346990
# 4             4                    Canada  ...               0.329570   0.458110
# ..          ...                       ...  ...                    ...        ...
# 444         292                    Guinea  ...               0.110938   0.264815
# 445         294                      Togo  ...               0.095665   0.196896
# 446         296                    Rwanda  ...               0.455220   0.252756
# 447         302                   Burundi  ...               0.084148   0.204435
# 448         304  Central African Republic  ...               0.056565   0.280876
#
# [449 rows x 12 columns]

# %% [markdown]
# ## Explore data

# %%
df_c["year"].value_counts()
# Out:
# 2015.0    158
# 2016.0    157
# 2017.0    134
# Name: year, dtype: int64

# %%
df_c["Region"].value_counts()
# Out:
# Sub-Saharan Africa                 78
# Central and Eastern Europe         58
# Latin America and Caribbean        46
# Western Europe                     42
# Africa                             40
# Middle East and Northern Africa    39
# Asia                               37
# Europe                             34
# Americas                           21
# Southeastern Asia                  18
# Southern Asia                      14
# Eastern Asia                       12
# Australia and New Zealand           4
# North America                       4
# Oceania                             2
# Name: Region, dtype: int64

# %%
df_c["Country"].value_counts()
# Out:
# Uzbekistan             3
# Trinidad and Tobago    3
# New Zealand            3
# Albania                3
# Nicaragua              3
#                       ..
# Oman                   1
# Somaliland region      1
# Djibouti               1
# Somaliland Region      1
# Puerto Rico            1
# Name: Country, Length: 164, dtype: int64

# %% [markdown]
# ## Drop columns unnecessary for machine learning

# %%
df_c = df_c.drop(["happiness_rank", "year", "Region", "Unnamed: 0"], axis='columns')
df_c.head()
# Out:
#        Country  happiness_score  ...  government_corruption  Generosity
# 0  Switzerland            7.587  ...                0.41978     0.29678
# 1      Iceland            7.561  ...                0.14145     0.43630
# 2      Denmark            7.527  ...                0.48357     0.34139
# 3       Norway            7.522  ...                0.36503     0.34699
# 4       Canada            7.427  ...                0.32957     0.45811
#
# [5 rows x 8 columns]

# %%
df_c.corr
# Out:
# <bound method DataFrame.corr of                       Country  ...  Generosity
# 0                 Switzerland  ...    0.296780
# 1                     Iceland  ...    0.436300
# 2                     Denmark  ...    0.341390
# 3                      Norway  ...    0.346990
# 4                      Canada  ...    0.458110
# ..                        ...  ...         ...
# 444                    Guinea  ...    0.264815
# 445                      Togo  ...    0.196896
# 446                    Rwanda  ...    0.252756
# 447                   Burundi  ...    0.204435
# 448  Central African Republic  ...    0.280876
#
# [449 rows x 8 columns]>

# %% [markdown]
# #### Data is being overfit so we will drop the countries

# %%
df_c
# Out:
#                       Country  ...  Generosity
# 0                 Switzerland  ...    0.296780
# 1                     Iceland  ...    0.436300
# 2                     Denmark  ...    0.341390
# 3                      Norway  ...    0.346990
# 4                      Canada  ...    0.458110
# ..                        ...  ...         ...
# 444                    Guinea  ...    0.264815
# 445                      Togo  ...    0.196896
# 446                    Rwanda  ...    0.252756
# 447                   Burundi  ...    0.204435
# 448  Central African Republic  ...    0.280876
#
# [449 rows x 8 columns]

# %% [markdown]
# ## View Correlation between columns after dropping country

# %%
corr_df = df_c.drop(["Country"], axis='columns')
corr_df
corr_df.corr
# Out:
# <bound method DataFrame.corr of      happiness_score  gpd_per_capita  ...  government_corruption  Generosity
# 0              7.587        1.396510  ...               0.419780    0.296780
# 1              7.561        1.302320  ...               0.141450    0.436300
# 2              7.527        1.325480  ...               0.483570    0.341390
# 3              7.522        1.459000  ...               0.365030    0.346990
# 4              7.427        1.326290  ...               0.329570    0.458110
# ..               ...             ...  ...                    ...         ...
# 444            3.507        0.244550  ...               0.110938    0.264815
# 445            3.495        0.305445  ...               0.095665    0.196896
# 446            3.471        0.368746  ...               0.455220    0.252756
# 447            2.905        0.091623  ...               0.084148    0.204435
# 448            2.693        0.000000  ...               0.056565    0.280876
#
# [449 rows x 7 columns]>

# %% [markdown]
# ## Train, Test, Split for ML

# %%
# Split our preprocessed data into our features and target arrays
X1 = df_c.drop(columns="happiness_score").values
y1 = df_c.happiness_score.values

# Split the preprocessed data into a training and testing dataset
X1_train, X1_test, y1_train, y1_test = train_test_split(X1, y1, random_state=42)
data = X1_train, X1_test, y1_train, y1_test

# %%
X1_test
# Out:
# [array([0.44314, 0.7741600000000001, 0.40457, 0.31056, 0.11681, 0.19103],
#        dtype=object),
#  array([0.55507, 0.57576, 0.04476, 0.40663, 0.1553, 0.20338], dtype=object),
#  array([0.52107, 1.01404, 0.36878, 0.10081, 0.1466, 0.19062], dtype=object),
#  array([1.53062355518341, 1.28667759895325, 0.590148329734802,
#         0.449750572443008, 0.27343225479126004, 0.147616013884544],
#        dtype=object),
#  array([1.0076100000000001, 0.98521, 0.7095, 0.56066, 0.07521, 0.37744],
#        dtype=object),
#  array([1.17898, 1.20643, 0.84483, 0.46363999999999994, 0.02652, 0.10686],
#        dtype=object),
#  array([1.39729, 0.92624, 0.79565, 0.32377, 0.0663, 0.25495], dtype=object),
#  array([1.02389, 0.9379299999999999, 0.64045, 0.3703, 0.16065, 0.07799],
#        dtype=object),
#  array([1.21768391132355, 1.15009129047394, 0.6851583123207089,
#         0.457003742456436, 0.00438790069893, 0.133519917726517],
#        dtype=object),
#  array([0.786441087722778, 1.5489691495895401, 0.498272627592087,
#         0.6582486629486078, 0.246528223156929, 0.41598364710807795],
#        dtype=object),
#  array([1.14723, 1.25745, 0.73128, 0.21341999999999997, 0.01031,
#         0.026410000000000003], dtype=object),
#  array([0.34193, 0.76062, 0.1501, 0.23501, 0.05269, 0.18386], dtype=object),
#  array([1.3559380769729599, 1.13136327266693, 0.84471470117569,
#         0.35511153936386103, 0.0412379764020443, 0.271254301071167],
#        dtype=object),
#  array([0.28123000000000004, 0.0, 0.24811, 0.34678000000000003, 0.11587,
#         0.17517], dtype=object),
#  array([0.783756256103516, 1.21577048301697, 0.0569157302379608,
#         0.394952565431595, 0.0261215660721064, 0.23094719648361198],
#        dtype=object),
#  array([0.564305365085602, 0.946018218994141, 0.132892116904259,
#         0.430388748645782, 0.0513066314160824, 0.23629845678806305],
#        dtype=object),
#  array([1.06098, 0.94632, 0.73172, 0.22815, 0.15746, 0.12253], dtype=object),
#  array([1.07838, 0.74173, 0.6353300000000001, 0.15111, 0.12721,
#         0.17190999999999998], dtype=object),
#  array([0.57939, 0.47493, 0.31048000000000003, 0.2287,
#         0.058920000000000014, 0.09821], dtype=object),
#  array([0.65435, 0.9043200000000001, 0.16007000000000002,
#         0.34334000000000003, 0.0403, 0.27233], dtype=object),
#  array([1.36066, 1.17278, 0.83096, 0.5814699999999999, 0.41903999999999997,
#         0.4940100000000001], dtype=object),
#  array([1.33358, 1.30923, 0.93156, 0.6512399999999999, 0.35636999999999996,
#         0.43562], dtype=object),
#  array([0.18847, 0.95152, 0.43873, 0.46581999999999996, 0.39928,
#         0.5031800000000001], dtype=object),
#  array([0.08308, 1.02626, 0.09131, 0.34037, 0.15603, 0.22269], dtype=object),
#  array([0.64499, 0.38174, 0.5152899999999999, 0.39786, 0.08492000000000001,
#         0.26475], dtype=object),
#  array([0.84731, 0.66366, 0.04991, 0.00589, 0.08434, 0.12070999999999996],
#        dtype=object),
#  array([1.15174, 1.22791, 0.77361, 0.44888, 0.15184, 0.0868], dtype=object),
#  array([0.9743799999999999, 0.9055700000000001, 0.72521, 0.1826, 0.14296,
#         0.1614], dtype=object),
#  array([1.22943, 0.95544, 0.57386, 0.4052, 0.11132, 0.15011], dtype=object),
#  array([0.99534, 0.972, 0.6082, 0.5965699999999999, 0.13633,
#         0.16990999999999998], dtype=object),
#  array([0.20868, 0.13995, 0.28443, 0.36453, 0.10730999999999999,
#         0.16680999999999999], dtype=object),
#  array([0.305808693170547, 0.9130203723907472, 0.375223308801651,
#         0.18919676542282104, 0.0672319754958153, 0.208732530474663],
#        dtype=object),
#  array([0.8282700000000001, 1.0870799999999998, 0.63793, 0.46611, 0.0,
#         0.51535], dtype=object),
#  array([1.6263433694839498, 1.2664102315902699, 0.726798236370087,
#         0.60834527015686, 0.324489563703537, 0.3609419465065], dtype=object),
#  array([0.26074, 1.03526, 0.20583, 0.38856999999999997, 0.12352, 0.18798],
#        dtype=object),
#  array([0.06831, 0.23442, 0.15747, 0.0432, 0.09419, 0.2029], dtype=object),
#  array([0.6364067792892459, 1.00318729877472, 0.25783589482307395,
#         0.461603492498398, 0.0782135501503944, 0.249580144882202],
#        dtype=object),
#  array([0.47428000000000003, 1.15115, 0.65088, 0.43477,
#         0.042319999999999997, 0.3003], dtype=object),
#  array([0.85769921541214, 1.25391757488251, 0.46800905466079706,
#         0.585214674472809, 0.0993318930268288, 0.193513423204422],
#        dtype=object),
#  array([0.9967299999999999, 0.86216, 0.60712, 0.36023, 0.13297, 0.14262],
#        dtype=object),
#  array([1.12373, 0.76042, 0.54504, 0.35327, 0.17914000000000002, 0.0564],
#        dtype=object),
#  array([0.11904179304838199, 0.8721179366111759, 0.229918196797371,
#         0.33288118243217496, 0.0389482490718365, 0.26654988527298],
#        dtype=object),
#  array([0.5455800000000001, 0.6795399999999999, 0.40131999999999995,
#         0.42341999999999996, 0.04355, 0.23087], dtype=object),
#  array([0.401477217674255, 0.581543326377869, 0.18074677884578694,
#         0.106179520487785, 0.0611578300595284, 0.311870932579041],
#        dtype=object),
#  array([1.2796399999999999, 1.0516299999999998, 0.68098,
#         0.41511000000000003, 0.18519000000000002, 0.08423], dtype=object),
#  array([1.1307767629623402, 1.49314916133881, 0.437726080417633,
#         0.41827192902565, 0.2592703402042389, 0.24992498755454998],
#        dtype=object),
#  array([1.15406, 0.9293299999999999, 0.88213, 0.07699,
#         0.013969999999999998, 0.0], dtype=object),
#  array([0.39724862575531, 0.601323127746582, 0.163486003875732,
#         0.147062435746193, 0.116793513298035, 0.285670816898346],
#        dtype=object),
#  array([0.77042, 1.10395, 0.57407, 0.5320600000000001, 0.15445, 0.47998],
#        dtype=object),
#  array([0.9669, 1.26504, 0.7385, 0.5566399999999999, 0.031869999999999996,
#         0.5763], dtype=object),
#  array([0.7682100000000001, 0.7771100000000001, 0.7299, 0.19847, 0.039,
#         0.07855], dtype=object),
#  array([1.1982743740081798, 1.33775317668915, 0.6376056075096129,
#         0.300740599632263, 0.0996715798974037, 0.0466930419206619],
#        dtype=object),
#  array([0.95395, 0.49813, 0.5211600000000001, 0.18847, 0.10393,
#         0.12705999999999998], dtype=object),
#  array([0.7710899999999999, 0.47798999999999997, 0.28212, 0.37938,
#         0.09752999999999999, 0.12077], dtype=object),
#  array([0.95578, 1.2378799999999999, 0.8602700000000001, 0.63376, 0.10583,
#         0.25497], dtype=object),
#  array([0.730573117733002, 1.14394497871399, 0.582569479942322,
#         0.348079860210419, 0.0733454525470734, 0.23618887364864305],
#        dtype=object),
#  array([0.98124, 1.2328700000000001, 0.69702, 0.49049, 0.17521, 0.14574],
#        dtype=object),
#  array([0.63069, 0.8192799999999999, 0.29759, 0.0, 0.10039,
#         0.18077000000000001], dtype=object),
#  array([0.4225, 0.8876700000000001, 0.23401999999999998, 0.49309, 0.05786,
#         0.20618000000000009], dtype=object),
#  array([1.3965100000000001, 1.34951, 0.9414299999999999, 0.66557,
#         0.41978000000000004, 0.29678000000000004], dtype=object),
#  array([1.42727, 1.12575, 0.80925, 0.64157, 0.38583, 0.26428], dtype=object),
#  array([1.11306, 0.92542, 0.67806, 0.21219000000000002, 0.00615, 0.12793],
#        dtype=object),
#  array([1.3145823478698702, 1.47351610660553, 0.62894994020462,
#         0.234231784939766, 0.0118656428530812, 0.010164656676352],
#        dtype=object),
#  array([0.59325, 1.14184, 0.7431399999999999, 0.55475, 0.19317, 0.27815],
#        dtype=object),
#  array([1.57352, 0.8711399999999999, 0.72993, 0.56215, 0.35561, 0.26591],
#        dtype=object),
#  array([0.521021246910095, 1.19009518623352, 0.0, 0.390661299228668,
#         0.119094640016556, 0.157497271895409], dtype=object),
#  array([1.09426, 0.89186, 0.34752, 0.44088999999999995,
#         0.10769000000000001, 0.12425], dtype=object),
#  array([1.18649, 0.6080899999999999, 0.70524, 0.23906999999999998, 0.04002,
#         0.18434], dtype=object),
#  array([0.8608600000000001, 0.6247699999999999, 0.64083, 0.14037,
#         0.036160000000000005, 0.07793], dtype=object),
#  array([0.925579309463501, 1.3682180643081698, 0.6410223841667181,
#         0.474307239055634, 0.0552677810192108, 0.23381833732128104],
#        dtype=object),
#  array([1.32792, 1.2993700000000001, 0.89186, 0.6147699999999999, 0.21843,
#         0.28214], dtype=object),
#  array([1.29121541976929, 1.28464603424072, 0.618784427642822,
#         0.4022649824619289, 0.0656007081270218, 0.416608929634094],
#        dtype=object),
#  array([0.83454, 0.8711899999999999, 0.5403899999999999, 0.50379, 0.08701,
#         0.28808], dtype=object),
#  array([0.74036, 0.29247, 0.45091000000000003, 0.40285, 0.08722, 0.25028],
#        dtype=object),
#  array([0.74553, 1.04356, 0.64425, 0.57733, 0.09472, 0.27489], dtype=object),
#  array([1.44787, 1.09774, 0.81487, 0.53466, 0.28551, 0.30451999999999996],
#        dtype=object),
#  array([0.964434325695038, 1.0984708070755, 0.33861181139946,
#         0.520303547382355, 0.0931469723582268, 0.0771337449550629],
#        dtype=object),
#  array([1.2994700000000001, 1.05613, 0.79151, 0.53164, 0.03635, 0.25738],
#        dtype=object),
#  array([0.69429, 0.7559600000000001, 0.5838300000000001, 0.26755, 0.06906,
#         0.2044], dtype=object),
#  array([0.6139100000000001, 0.8414200000000001, 0.28639000000000003,
#         0.1268, 0.17955, 0.22685999999999998], dtype=object),
#  array([1.1531838178634601, 1.2108621597290001, 0.709978997707367,
#         0.412730008363724, 0.132774114608765, 0.12099043279886199],
#        dtype=object),
#  array([1.04424, 1.25596, 0.7205199999999999, 0.42908, 0.11069000000000001,
#         0.058410000000000004], dtype=object),
#  array([1.24461, 0.9577399999999999, 0.9653799999999999,
#         0.33208000000000004, 0.07857, 0.18557], dtype=object),
#  array([0.381430715322495, 1.12982773780823, 0.21763260662555706,
#         0.443185955286026, 0.057069718837738, 0.32576605677604703],
#        dtype=object),
#  array([0.24454993009567305, 0.7912446856498722, 0.194129139184952,
#         0.348587512969971, 0.110937617719173, 0.264815092086792],
#        dtype=object),
#  array([0.368610262870789, 0.640449821949005, 0.277321130037308,
#         0.0303698573261499, 0.0998721495270729, 0.4892037808895109],
#        dtype=object),
#  array([1.0352252721786501, 1.21877038478851, 0.6301661133766171,
#         0.4500028789043429, 0.0470490865409374, 0.126819714903831],
#        dtype=object),
#  array([0.9001899999999999, 0.97459, 0.73017, 0.4149600000000001, 0.05989,
#         0.14982], dtype=object),
#  array([0.16192533075809498, 0.993025004863739, 0.26850500702858,
#         0.36365869641304, 0.13857294619083402, 0.22867384552955602],
#        dtype=object),
#  array([1.0635299999999999, 1.1985, 0.79661, 0.5421, 0.0927, 0.24434],
#        dtype=object),
#  array([1.33596, 1.36948, 0.89533, 0.6177699999999999, 0.28703,
#         0.45901000000000003], dtype=object),
#  array([1.20813, 0.89318, 0.92356, 0.40671999999999997, 0.06146,
#         0.30638000000000004], dtype=object),
#  array([1.4834100000000001, 1.16157, 0.81455, 0.54008, 0.29754,
#         0.44963000000000003], dtype=object),
#  array([0.8405799999999999, 0.38595, 0.5947100000000001,
#         0.25645999999999997, 0.08404, 0.040530000000000004], dtype=object),
#  array([1.06166, 1.2089, 0.8116, 0.6036199999999999, 0.24558000000000002,
#         0.2324], dtype=object),
#  array([0.47038, 0.91612, 0.29924, 0.48827, 0.12468, 0.19591], dtype=object),
#  array([1.00726580619812, 0.8683514595031742, 0.613212049007416,
#         0.289680689573288, 0.0867231488227844, 0.0496933571994305],
#        dtype=object),
#  array([1.00082039833069, 1.2861688137054401, 0.685636222362518,
#         0.4551981985569, 0.140134647488594, 0.15011246502399406],
#        dtype=object),
#  array([1.2167, 0.9058700000000001, 0.8188300000000001, 0.37789,
#         0.11450999999999999, 0.31595], dtype=object),
#  array([0.63107, 0.49353, 0.29681, 0.40973000000000004, 0.0326,
#         0.21203000000000002], dtype=object),
#  array([0.8786700000000001, 0.8043399999999999, 0.81325,
#         0.35733000000000004, 0.06412999999999999, 0.14272], dtype=object),
#  array([0.81217, 0.87877, 0.4703600000000001, 0.5485399999999999,
#         0.11757000000000001, 0.21674000000000002], dtype=object),
#  array([0.97306, 0.85974, 0.68613, 0.4027, 0.18037, 0.10074], dtype=object),
#  array([0.982409417629242, 1.0693359375, 0.705186307430267,
#         0.204403176903725, 0.0, 0.328867495059967], dtype=object),
#  array([1.5649795532226598, 1.51691174507141, 0.858131289482117,
#         0.620070576667786, 0.3670072853565221, 0.29054927825927696],
#        dtype=object),
#  array([1.42539, 1.05249, 0.8195899999999999, 0.51354, 0.26248, 0.2424],
#        dtype=object),
#  array([0.59532, 0.9534799999999999, 0.6951, 0.40148, 0.06825,
#         0.23026999999999997], dtype=object),
#  array([1.3412059545516999, 1.4525188207626298, 0.7908282279968258,
#         0.572575807571411, 0.0451289787888527, 0.242649093270302],
#        dtype=object),
#  array([1.29025, 1.31826, 0.8891100000000001, 0.64169, 0.41372, 0.23351],
#        dtype=object),
#  array([1.27074, 1.25712, 0.99111, 0.49615, 0.1806, 0.10705], dtype=object),
#  array([0.28665, 0.35386, 0.3191, 0.4845, 0.0801, 0.1826], dtype=object),
#  array([0.10705999999999999, 0.50353, 0.23165, 0.25748000000000004,
#         0.04852, 0.24063], dtype=object),
#  array([0.8781145811080929, 0.774864435195923, 0.59771066904068,
#         0.408158332109451, 0.0877631828188896, 0.0322099551558495],
#        dtype=object)]

# %% [markdown]
# ## Save out list of countries and features data

# %%
countries_train = [x[0] for x in X1_train]
countries_test = [x[0] for x in X1_test]

# %%
X1_train = [x[1:] for x in X1_train]
X1_test = [x[1:] for x in X1_test]

# %%
compare_df = pd.DataFrame({'country':countries_test, 'actual': y1_test, 'predicted': 'pred'})
compare_df
# Out:
#           country  actual predicted
# 0         Senegal   4.219      pred
# 1     Ivory Coast   3.916      pred
# 2           Sudan   4.550      pred
# 3    Saudi Arabia   6.344      pred
# 4       Mauritius   5.477      pred
# ..            ...     ...       ...
# 108       Finland   7.406      pred
# 109         Japan   5.987      pred
# 110         Benin   3.340      pred
# 111       Liberia   3.622      pred
# 112       Morocco   5.235      pred
#
# [113 rows x 3 columns]

# %% [markdown]
# ## Scale our data

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X1_scaler = scaler.fit(X1_train)

# Scale the data
X1_train_scaled = X1_scaler.transform(X1_train)
X1_test_scaled = X1_scaler.transform(X1_test)

# %%
data= [X1_train_scaled, X1_test_scaled, y1_train, y1_test]

# %% [markdown]
# ## Run ML models

# %%
from sklearn.linear_model import LinearRegression
classifier = LinearRegression()
# classifier

# Fit the model to the data
classifier.fit(X1_train_scaled, y1_train)

print(f"Training Data Score: {classifier.score(X1_train_scaled, y1_train)}")
print(f"Testing Data Score: {classifier.score(X1_test_scaled, y1_test)}")

predictions_clr = classifier.predict(X1_test_scaled)
predictions_df= pd.DataFrame({"Prediction": predictions_clr, "Actual": y1_test})
predictions_df
# Out:
# Training Data Score: 0.7393901378351614
# Testing Data Score: 0.8494853874320927
#      Prediction  Actual
# 0      4.334137   4.219
# 1      4.105379   3.916
# 2      4.231418   4.550
# 3      6.352160   6.344
# 4      5.857241   5.477
# ..          ...     ...
# 108    6.868960   7.406
# 109    6.488988   5.987
# 110    4.045141   3.340
# 111    3.500724   3.622
# 112    5.091506   5.235
#
# [113 rows x 2 columns]

# %%
from sklearn.ensemble import RandomForestRegressor
clf = RandomForestRegressor().fit(X1_train_scaled, y1_train)
print(f'Training Score: {clf.score(X1_train_scaled, y1_train)}')
print(f'Testing Score: {clf.score(X1_test_scaled, y1_test)}')

predictions_c = clf.predict(X1_test_scaled)
predictions_df= pd.DataFrame({"Prediction": predictions_c, "Actual": y1_test})
predictions_df
# Out:
# Training Score: 0.971337440191773
# Testing Score: 0.8096156205754678
#      Prediction  Actual
# 0       4.15099   4.219
# 1       4.29400   3.916
# 2       4.19225   4.550
# 3       6.18097   6.344
# 4       4.86175   5.477
# ..          ...     ...
# 108     7.19619   7.406
# 109     6.10752   5.987
# 110     3.80070   3.340
# 111     3.81017   3.622
# 112     5.28946   5.235
#
# [113 rows x 2 columns]

# %%
# from sklearn.ensemble import Lasso
clf = linear_model.Lasso(alpha=.001).fit(X1_train_scaled, y1_train)
print(f'Training Score: {clf.score(X1_train_scaled, y1_train)}')
print(f'Testing Score: {clf.score(X1_test_scaled, y1_test)}')

predictions_lasso = clf.predict(X1_test_scaled)
predictions_l_df= pd.DataFrame({"Lasso Prediction": predictions_lasso, "Actual": y1_test})
predictions_l_df
# Out:
# Training Score: 0.7393882377459953
# Testing Score: 0.8492500569803096
#      Lasso Prediction  Actual
# 0            4.335502   4.219
# 1            4.107270   3.916
# 2            4.232256   4.550
# 3            6.351271   6.344
# 4            5.856566   5.477
# ..                ...     ...
# 108          6.866531   7.406
# 109          6.488401   5.987
# 110          4.047649   3.340
# 111          3.503025   3.622
# 112          5.093423   5.235
#
# [113 rows x 2 columns]

# %%
from sklearn.svm import SVR
model2 = SVR(kernel='rbf', C=1.0, epsilon=.001) # set kernel and hyperparameters
svr = model2.fit(X1_train_scaled, y1_train)
print(f'Training Score: {svr.score(X1_train_scaled, y1_train)}')
print(f'Testing Score: {svr.score(X1_test_scaled, y1_test)}')

predictions_svr = svr.predict(X1_test_scaled)
predictions_svr_df= pd.DataFrame({"SVR Prediction": predictions_svr, "Actual": y1_test})
predictions_svr_df
# Out:
# Training Score: 0.8494933797860317
# Testing Score: 0.858728773446082
#      SVR Prediction  Actual
# 0          4.188270   4.219
# 1          4.162281   3.916
# 2          4.277339   4.550
# 3          5.825041   6.344
# 4          5.847854   5.477
# ..              ...     ...
# 108        7.222481   7.406
# 109        6.233820   5.987
# 110        3.881112   3.340
# 111        3.403106   3.622
# 112        5.059691   5.235
#
# [113 rows x 2 columns]

# %% [markdown]
# ## Save DataFrame containing data for export

# %%
compare_df = pd.DataFrame({'country':countries_test, 'actual': y1_test, 'svr predicted': predictions_svr, 'linear predicted': predictions_clr, 'lasso predicted': predictions_lasso, 'random forest':predictions_c})
compare_df
# Out:
#           country  actual  ...  lasso predicted  random forest
# 0         Senegal   4.219  ...         4.335502        4.15099
# 1     Ivory Coast   3.916  ...         4.107270        4.29400
# 2           Sudan   4.550  ...         4.232256        4.19225
# 3    Saudi Arabia   6.344  ...         6.351271        6.18097
# 4       Mauritius   5.477  ...         5.856566        4.86175
# ..            ...     ...  ...              ...            ...
# 108       Finland   7.406  ...         6.866531        7.19619
# 109         Japan   5.987  ...         6.488401        6.10752
# 110         Benin   3.340  ...         4.047649        3.80070
# 111       Liberia   3.622  ...         3.503025        3.81017
# 112       Morocco   5.235  ...         5.093423        5.28946
#
# [113 rows x 6 columns]

# %%
compare_df.to_csv("/content/drive/MyDrive/Colab Notebooks/p4/prediction_comparison.csv", index= False)

# %%
# %matplotlib inline
from matplotlib import pyplot as plt
import numpy as np
from sklearn.linear_model import LinearRegression, Ridge, Lasso, ElasticNet
from sklearn.svm import SVR

from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor, ExtraTreesRegressor, AdaBoostRegressor
from sklearn.svm import SVR

# %%
    data = X1_train_scaled, X1_test_scaled, y1_train, y1_test

# %%
def test_model(model, data):
    X1_train_scaled, X1_test_scaled, y1_train, y1_test = data
    reg = model.fit(X1_train_scaled, y1_train)
    print(f'Model: {type(reg).__name__}')
    print(f'Train score: {reg.score(X1_train_scaled, y1_train)}')
    print(f'Test Score: {reg.score(X1_test_scaled, y1_test)}\n')
    plt.show()

# %%
test_model(LinearRegression(), data)
test_model(Ridge(), data)
test_model(Lasso(alpha = .001), data)
test_model(ElasticNet(), data)
test_model(SVR(C=1.0, epsilon=0.001), data)
test_model(KNeighborsRegressor(), data)
test_model(RandomForestRegressor(random_state=1, n_estimators=100), data)
test_model(ExtraTreesRegressor(), data)
test_model(AdaBoostRegressor(), data)
# Out:
# Model: LinearRegression
# Train score: 0.7393901378351614
# Test Score: 0.8494853874320927
#
# Model: Ridge
# Train score: 0.7393880852483157
# Test Score: 0.849521505688118
#
# Model: Lasso
# Train score: 0.7393882377459953
# Test Score: 0.8492500569803096
#
# Model: ElasticNet
# Train score: 0.36889495181065124
# Test Score: 0.3764101126508038
#
# Model: SVR
# Train score: 0.8494933797860317
# Test Score: 0.858728773446082
#
# Model: KNeighborsRegressor
# Train score: 0.8624256742518872
# Test Score: 0.8070943187204942
#
# Model: RandomForestRegressor
# Train score: 0.9717845928130108
# Test Score: 0.8089776021871344
#
# Model: ExtraTreesRegressor
# Train score: 1.0
# Test Score: 0.8372651288109608
#
# Model: AdaBoostRegressor
# Train score: 0.8322759534646937
# Test Score: 0.7960235259081593

# %% [markdown]
# ## Separate Training Dataset and Testing Dataset

# %%
train_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/p4/FINAL_data.csv")
test_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/p4/2019_updated.csv")
train_df
# Out:
#      Unnamed: 0                   Country  ...  government_corruption Generosity
# 0             0               Switzerland  ...               0.419780   0.296780
# 1             1                   Iceland  ...               0.141450   0.436300
# 2             2                   Denmark  ...               0.483570   0.341390
# 3             3                    Norway  ...               0.365030   0.346990
# 4             4                    Canada  ...               0.329570   0.458110
# ..          ...                       ...  ...                    ...        ...
# 444         292                    Guinea  ...               0.110938   0.264815
# 445         294                      Togo  ...               0.095665   0.196896
# 446         296                    Rwanda  ...               0.455220   0.252756
# 447         302                   Burundi  ...               0.084148   0.204435
# 448         304  Central African Republic  ...               0.056565   0.280876
#
# [449 rows x 12 columns]

# %%
test_df
# Out:
#      Unnamed: 0                   Country  ...  Generosity government_corruption
# 0             0                   Finland  ...       0.153                 0.393
# 1             1                   Denmark  ...       0.252                 0.410
# 2             2                    Norway  ...       0.271                 0.341
# 3             3                   Iceland  ...       0.354                 0.118
# 4             4               Netherlands  ...       0.322                 0.298
# ..          ...                       ...  ...         ...                   ...
# 266         266                  Viet Nam  ...         NaN                   NaN
# 267         267  Virgin Islands (British)  ...         NaN                   NaN
# 268         268     Virgin Islands (U.S.)  ...         NaN                   NaN
# 269         269         Wallis and Futuna  ...         NaN                   NaN
# 270         270            Western Sahara  ...         NaN                   NaN
#
# [271 rows x 11 columns]

# %%
test_df = test_df.drop(["happiness_rank", "year", "Region", "Unnamed: 0"], axis='columns')
test_df.head()
# Out:
#        Country  happiness_score  ...  Generosity  government_corruption
# 0      Finland            7.769  ...       0.153                  0.393
# 1      Denmark            7.600  ...       0.252                  0.410
# 2       Norway            7.554  ...       0.271                  0.341
# 3      Iceland            7.494  ...       0.354                  0.118
# 4  Netherlands            7.488  ...       0.322                  0.298
#
# [5 rows x 7 columns]

# %%
test_df = test_df.dropna()

# %%
train_df = train_df.drop(["happiness_rank", "year", "Region", "Unnamed: 0", "Family"], axis='columns').rename(columns={"gpd_per_capita": "gdp_per_capita"})
train_df.head()
# Out:
#        Country  happiness_score  ...  government_corruption  Generosity
# 0  Switzerland            7.587  ...                0.41978     0.29678
# 1      Iceland            7.561  ...                0.14145     0.43630
# 2      Denmark            7.527  ...                0.48357     0.34139
# 3       Norway            7.522  ...                0.36503     0.34699
# 4       Canada            7.427  ...                0.32957     0.45811
#
# [5 rows x 7 columns]

# %%
train_df = train_df.loc[:, ["Country","happiness_score","gdp_per_capita","life_expectancy", "Freedom", "Generosity", "government_corruption"]]
train_df.head()
# Out:
#        Country  happiness_score  ...  Generosity  government_corruption
# 0  Switzerland            7.587  ...     0.29678                0.41978
# 1      Iceland            7.561  ...     0.43630                0.14145
# 2      Denmark            7.527  ...     0.34139                0.48357
# 3       Norway            7.522  ...     0.34699                0.36503
# 4       Canada            7.427  ...     0.45811                0.32957
#
# [5 rows x 7 columns]

# %%
train_df = train_df.dropna()

# %%
# Split our preprocessed data into our features and target arrays
X_train = train_df.drop(columns="happiness_score").values
y_train = train_df.happiness_score.values

# %%
X_test = test_df.drop(columns="happiness_score").values
y_test = test_df["happiness_score"]

# %%
countries_train_df = [x[0] for x in X_train]
countries_test_df = [x[0] for x in X_test]

# %%
X_train = [x[1:] for x in X_train]
X_test = [x[1:] for x in X_test]

# %%
train_countries_df = pd.DataFrame({'country':countries_test_df, 'actual': y_test, 'linear predicted': "linear pred", 'random forest': "random pred"})
train_countries_df
# Out:
#                       country  actual linear predicted random forest
# 0                     Finland   7.769      linear pred   random pred
# 1                     Denmark   7.600      linear pred   random pred
# 2                      Norway   7.554      linear pred   random pred
# 3                     Iceland   7.494      linear pred   random pred
# 4                 Netherlands   7.488      linear pred   random pred
# ..                        ...     ...              ...           ...
# 151                    Rwanda   3.334      linear pred   random pred
# 152                  Tanzania   3.231      linear pred   random pred
# 153               Afghanistan   3.203      linear pred   random pred
# 154  Central African Republic   3.083      linear pred   random pred
# 155               South Sudan   2.853      linear pred   random pred
#
# [156 rows x 4 columns]

# %%
# Create a StandardScaler instances
scaler = StandardScaler()

# Fit the StandardScaler
X_scaler = scaler.fit(X_train)

# Scale the data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)

# %%
data_full = X_train_scaled, X_test_scaled, y_train, y_test

# %%
test_model(LinearRegression(), data_full)
test_model(Ridge(), data_full)
test_model(Lasso(alpha = .001), data_full)
test_model(ElasticNet(), data_full)
test_model(SVR(C=1.0, epsilon=0.001), data_full)
test_model(KNeighborsRegressor(), data_full)
test_model(RandomForestRegressor(random_state=1, n_estimators=100), data_full)
test_model(ExtraTreesRegressor(), data_full)
test_model(AdaBoostRegressor(), data_full)
# Out:
# Model: LinearRegression
# Train score: 0.7492152696573513
# Test Score: 0.7424098343108443
#
# Model: Ridge
# Train score: 0.7492137656061356
# Test Score: 0.7423711491250571
#
# Model: Lasso
# Train score: 0.7492135374402564
# Test Score: 0.7423911467458693
#
# Model: ElasticNet
# Train score: 0.3826971862340699
# Test Score: 0.38850610377388595
#
# Model: SVR
# Train score: 0.8400303416082049
# Test Score: 0.727467885518607
#
# Model: KNeighborsRegressor
# Train score: 0.8869434497248354
# Test Score: 0.7071125566971534
#
# Model: RandomForestRegressor
# Train score: 0.9723293350287089
# Test Score: 0.647138257246858
#
# Model: ExtraTreesRegressor
# Train score: 1.0
# Test Score: 0.6896913827201805
#
# Model: AdaBoostRegressor
# Train score: 0.81767842280203
# Test Score: 0.6681604251232445

# %%
from sklearn.svm import SVR
model2 = SVR(kernel='rbf', C=1.0, epsilon=.001) # set kernel and hyperparameters
svr = model2.fit(X_train_scaled, y_train)
print(f'Training Score: {svr.score(X_train_scaled, y_train)}')
print(f'Testing Score: {svr.score(X_test_scaled, y_test)}')

ttf_predictions_svr = svr.predict(X_test_scaled)
predictions_ttf_svr_df= pd.DataFrame({"SVR Prediction": ttf_predictions_svr, "Actual": y_test})
predictions_ttf_svr_df
# Out:
# Training Score: 0.8400303416082049
# Testing Score: 0.727467885518607
#      SVR Prediction  Actual
# 0          6.613931   7.769
# 1          7.135372   7.600
# 2          7.009200   7.554
# 3          6.781082   7.494
# 4          7.083237   7.488
# ..              ...     ...
# 151        4.494115   3.334
# 152        4.808172   3.231
# 153        3.730025   3.203
# 154        3.517351   3.083
# 155        3.631911   2.853
#
# [156 rows x 2 columns]

# %%
from sklearn.linear_model import LinearRegression
classifier = LinearRegression()
# classifier

# Fit the model to the data
classifier.fit(X_train_scaled, y_train)

print(f"Training Data Score: {classifier.score(X_train_scaled, y_train)}")
print(f"Testing Data Score: {classifier.score(X_test_scaled, y_test)}")

predictions_ttf_clr = classifier.predict(X_test_scaled)
predictions_ttf_df= pd.DataFrame({"Prediction": predictions_ttf_clr, "Actual": y_test})
predictions_ttf_df
# Out:
# Training Data Score: 0.7492152696573513
# Testing Data Score: 0.7424098343108443
#      Prediction  Actual
# 0      6.899565   7.769
# 1      7.020708   7.600
# 2      7.186533   7.554
# 3      6.926663   7.494
# 4      6.942099   7.488
# ..          ...     ...
# 151    5.119618   3.334
# 152    4.736554   3.231
# 153    3.471835   3.203
# 154    3.204270   3.083
# 155    3.413541   2.853
#
# [156 rows x 2 columns]

# %%
# from sklearn.ensemble import Lasso
clf = linear_model.Lasso(alpha=.001).fit(X_train_scaled, y_train)
print(f'Training Score: {clf.score(X_train_scaled, y_train)}')
print(f'Testing Score: {clf.score(X_test_scaled, y_test)}')

predictions_ttf_lasso = clf.predict(X_test_scaled)
predictions_ttf_df= pd.DataFrame({"Lasso Prediction": predictions_ttf_lasso, "Actual": y_test})
predictions_ttf_df
# Out:
# Training Score: 0.7492135374402564
# Testing Score: 0.7423911467458693
#      Lasso Prediction  Actual
# 0            6.897753   7.769
# 1            7.018174   7.600
# 2            7.183963   7.554
# 3            6.924602   7.494
# 4            6.939602   7.488
# ..                ...     ...
# 151          5.119137   3.334
# 152          4.736947   3.231
# 153          3.474305   3.203
# 154          3.206719   3.083
# 155          3.415631   2.853
#
# [156 rows x 2 columns]

# %%
full_ttf_compare_df = pd.DataFrame({'Country':countries_test_df, 'Actual_Score': y_test, 'SVR_Prediction': ttf_predictions_svr, 'Linear_Reg_Prediction': predictions_ttf_clr, 'Lasso_Prediction': predictions_ttf_lasso})
full_ttf_compare_df
# Out:
#                       Country  ...  Lasso_Prediction
# 0                     Finland  ...          6.897753
# 1                     Denmark  ...          7.018174
# 2                      Norway  ...          7.183963
# 3                     Iceland  ...          6.924602
# 4                 Netherlands  ...          6.939602
# ..                        ...  ...               ...
# 151                    Rwanda  ...          5.119137
# 152                  Tanzania  ...          4.736947
# 153               Afghanistan  ...          3.474305
# 154  Central African Republic  ...          3.206719
# 155               South Sudan  ...          3.415631
#
# [156 rows x 5 columns]

# %%
full_ttf_compare_df = full_ttf_compare_df.sort_values(by = 'Country').round(4)
full_ttf_compare_df
# Out:
#          Country  Actual_Score  ...  Linear_Reg_Prediction  Lasso_Prediction
# 153  Afghanistan         3.203  ...                 3.4718            3.4743
# 106      Albania         4.719  ...                 5.6312            5.6316
# 87       Algeria         5.211  ...                 5.0260            5.0272
# 46     Argentina         6.086  ...                 5.9550            5.9556
# 115      Armenia         4.559  ...                 5.2210            5.2221
# ..           ...           ...  ...                    ...               ...
# 107    Venezuela         4.707  ...                 5.0805            5.0819
# 93       Vietnam         5.175  ...                 5.6507            5.6511
# 150        Yemen         3.380  ...                 3.7951            3.7974
# 137       Zambia         4.107  ...                 4.7551            4.7559
# 145     Zimbabwe         3.663  ...                 4.3059            4.3076
#
# [156 rows x 5 columns]

# %%
full_ttf_compare_df.to_csv("/content/drive/MyDrive/Colab Notebooks/p4/prediction_2019_comparison.csv", index= False)

# %%
import pymongo 

connection_string = "mongodb://localhost:27017"

client = pymongo.MongoClient(connection_string)

# Declare the database
db = client.happy_db

# # Declare the collection
country_predict = db.country_predict

# train_countries_df.reset_index(inplace=True)
data_dict = train_countries_df.to_dict("records")
country_predict.insert_many(data_dict)

print("ETL Complete")
# Out:
# ---------------------------------------------------------------------------
# ServerSelectionTimeoutError               Traceback (most recent call last)
# <ipython-input-36-8e3efab5796f> in <module>()
#      13 # train_countries_df.reset_index(inplace=True)
#      14 data_dict = train_countries_df.to_dict("records")
# ---> 15 country_predict.insert_many(data_dict)
#      16
#      17 print("ETL Complete")
#
# /usr/local/lib/python3.7/dist-packages/pymongo/collection.py in insert_many(self, documents, ordered, bypass_document_validation, session)
#     768         blk = _Bulk(self, ordered, bypass_document_validation)
#     769         blk.ops = [doc for doc in gen()]
# --> 770         blk.execute(write_concern, session=session)
#     771         return InsertManyResult(inserted_ids, write_concern.acknowledged)
#     772
#
# /usr/local/lib/python3.7/dist-packages/pymongo/bulk.py in execute(self, write_concern, session)
#     531                 self.execute_no_results(sock_info, generator)
#     532         else:
# --> 533             return self.execute_command(generator, write_concern, session)
#     534
#     535
#
# /usr/local/lib/python3.7/dist-packages/pymongo/bulk.py in execute_command(self, generator, write_concern, session)
#     359
#     360         client = self.collection.database.client
# --> 361         with client._tmp_session(session) as s:
#     362             client._retry_with_session(
#     363                 self.is_retryable, retryable_bulk, s, self)
#
# /usr/lib/python3.7/contextlib.py in __enter__(self)
#     110         del self.args, self.kwds, self.func
#     111         try:
# --> 112             return next(self.gen)
#     113         except StopIteration:
#     114             raise RuntimeError("generator didn't yield") from None
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _tmp_session(self, session, close)
#    1946             return
#    1947
# -> 1948         s = self._ensure_session(session)
#    1949         if s:
#    1950             try:
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _ensure_session(self, session)
#    1933             # Don't make implicit sessions causally consistent. Applications
#    1934             # should always opt-in.
# -> 1935             return self.__start_session(True, causal_consistency=False)
#    1936         except (ConfigurationError, InvalidOperation):
#    1937             # Sessions not supported, or multiple users authenticated.
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in __start_session(self, implicit, **kwargs)
#    1881
#    1882         # Raises ConfigurationError if sessions are not supported.
# -> 1883         server_session = self._get_server_session()
#    1884         opts = client_session.SessionOptions(**kwargs)
#    1885         return client_session.ClientSession(
#
# /usr/local/lib/python3.7/dist-packages/pymongo/mongo_client.py in _get_server_session(self)
#    1919     def _get_server_session(self):
#    1920         """Internal: start or resume a _ServerSession."""
# -> 1921         return self._topology.get_server_session()
#    1922
#    1923     def _return_server_session(self, server_session, lock):
#
# /usr/local/lib/python3.7/dist-packages/pymongo/topology.py in get_server_session(self)
#     518             # Sessions are always supported in load balanced mode.
#     519             if not self._settings.load_balanced:
# --> 520                 session_timeout = self._check_session_support()
#     521             else:
#     522                 # Sessions never time out in load balanced mode.
#
# /usr/local/lib/python3.7/dist-packages/pymongo/topology.py in _check_session_support(self)
#     500                         any_server_selector,
#     501                         self._settings.server_selection_timeout,
# --> 502                         None)
#     503             elif not self._description.readable_servers:
#     504                 self._select_servers_loop(
#
# /usr/local/lib/python3.7/dist-packages/pymongo/topology.py in _select_servers_loop(self, selector, timeout, address)
#     218                 raise ServerSelectionTimeoutError(
#     219                     "%s, Timeout: %ss, Topology Description: %r" %
# --> 220                     (self._error_message(selector), timeout, self.description))
#     221
#     222             self._ensure_opened()
#
# ServerSelectionTimeoutError: localhost:27017: [Errno 111] Connection refused, Timeout: 30s, Topology Description: <TopologyDescription id: 61b0237b299f14ae649421af, topology_type: Single, servers: [<ServerDescription ('localhost', 27017) server_type: Unknown, rtt: None, error=AutoReconnect('localhost:27017: [Errno 111] Connection refused')>]>

# %% [markdown]
# ## Trend Line Prep

# %%
tl5_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/p4/2015.csv")
tl5_df
fift = loc[:,['Country','happiness_score']]
# Out:
#          Country  ... Dystopia Residual
# 0    Switzerland  ...           2.51738
# 1        Iceland  ...           2.70201
# 2        Denmark  ...           2.49204
# 3         Norway  ...           2.46531
# 4         Canada  ...           2.45176
# ..           ...  ...               ...
# 153       Rwanda  ...           0.67042
# 154        Benin  ...           1.63328
# 155        Syria  ...           0.32858
# 156      Burundi  ...           1.83302
# 157         Togo  ...           1.56726
#
# [158 rows x 12 columns]

# %%
tl6_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/p4/2016.csv")
tl6_df
six = loc[:,['Country','happiness_score']]

# %%
tl7_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/p4/2017.csv")
tl7_df
sv = loc[:,['Country','happiness_score']]

# %%
tl8_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/p4/2018.csv")
tl8_df
eight = loc[:,['Country','happiness_score']]

# %%
tl9_df = pd.read_csv("/content/drive/MyDrive/Colab Notebooks/p4/2019.csv")
tl9_df
nine = loc[:,['Country','happiness_score']]

# %%
trendline_df = pd.DataFrame({'country':countries_test, 'actual': y1_test, 'svr predicted': predictions_svr})
trendline_df

# %% [markdown]
# # Unused Machine Learning Code

# %%
number_input_features = len(X1_train[0])
hidden_nodes_layer1 = 20

nn_model = tf.keras.models.Sequential()

# First hidden layer
nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer1, activation="relu", input_dim=number_input_features))

# Second hidden layer
# nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer2, activation="relu"))

# Second hidden layer
# nn_model.add(tf.keras.layers.Dense(units=hidden_nodes_layer3, activation="relu"))

# Output layer
nn_model.add(tf.keras.layers.Dense(units=1, activation="sigmoid"))

# Check the structure of the model
nn_model.summary()

# %%
nn_model.compile(loss="binary_crossentropy", optimizer="adam", metrics=["accuracy"])

# %%
fit_model = nn_model.fit(X1_train_scaled, y1_train, epochs=20)

# %%
from sklearn.isotonic import IsotonicRegression
# iso = IsotonicRegression().fit(X1_train_scaled, y1_train)
model3 = IsotonicRegression() # set kernel and hyperparameters
iso = model3.fit(X1_train_scaled, y1_train)
# # X, y = make_regression(n_samples=10, n_features=1, random_state=41)
# # >>> iso_reg.predict([.1, .2])
# print(f'Training Score: {iso.score(X1_train_scaled, y1_train)}')
# print(f'Testing Score: {iso.score(X1_test_scaled, y1_test)}')

predictions_iso = iso.predict(X1_test_scaled)
predictions_iso_df= pd.DataFrame({"Iso Prediction": predictions_iso, "Actual": y1_test})
predictions_iso_df

# %%
# Plot outputs
plt.scatter(X1_test, y1_test, color="black")
# plt.plot(y1_test, predictions_clr, color="blue", linewidth=3)

plt.xticks(())
plt.yticks(())

plt.show()

# %%
import mpl_toolkits.mplot3d.axes3d as p3
# #############################################################################
# Plot the result
fig = plt.figure()
ax = p3.Axes3D(fig)
ax.view_init(7, -80)
ax.scatter(X1[0], X1[1], X1[2],
           color=plt.cm.jet(y1/y1.max()),
           s=20, edgecolor='k')
plt.show()
